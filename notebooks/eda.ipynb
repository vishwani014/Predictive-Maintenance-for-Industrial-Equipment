# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../data/processed_data.csv')
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M             0.304348                 0.358025
# 1    2     L47181    L             0.315217                 0.370370
# 2    3     L47182    L             0.304348                 0.345679
# 3    4     L47183    L             0.315217                 0.358025
# 4    5     L47184    L             0.315217                 0.370370
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  TWF  \
# 0                0.222934     0.535714         0.000000                0    0
# 1                0.139697     0.583791         0.011858                0    0
# 2                0.192084     0.626374         0.019763                0    0
# 3                0.154249     0.490385         0.027668                0    0
# 4                0.139697     0.497253         0.035573                0    0
#
#    ...  RNF  Failure  Temp_Diff  Torque_RPM_Ratio  \
# 0  ...    0        1   0.644444          0.420343
# 1  ...    0        1   0.644444          0.504935
# 2  ...    0        1   0.622222          0.506435
# 3  ...    0        1   0.622222          0.419854
# 4  ...    0        1   0.644444          0.433363
#
#    Air temperature [K]_Rolling_Mean  Air temperature [K]_Rolling_Std  \
# 0                          0.303965                              NaN
# 1                          0.309471                         0.310087
# 2                          0.307636                         0.253185
# 3                          0.309471                         0.253185
# 4                          0.310573                         0.240192
#
#    Process temperature [K]_Rolling_Mean  Process temperature [K]_Rolling_Std  \
# 0                              0.357683                                  NaN
# 1                              0.363980                             0.273179
# 2                              0.357683                             0.386334
# 3                              0.357683                             0.315440
# 4                              0.360202                             0.323230
#
#    Torque [Nm]_Rolling_Mean  Torque [Nm]_Rolling_Std
# 0                  0.573414                      NaN
# 1                  0.626284                 0.068260
# 2                  0.675126                 0.102762
# 3                  0.624773                 0.143857
# 4                  0.597583                 0.141185
#
# [5 rows x 23 columns]

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Sensor Features')
plt.savefig('../results/eda_plots/correlation_heatmap.png')
plt.close()
